# %% [markdown]
# Student Performance Indicator

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv("raw.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %% [markdown]
# 2.2 Dataset Information

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Check Duplicate Value

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# Checking the number of uniques values of each column

# %%
df.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# dtype: int64

# %% [markdown]
# Check statistics of data set

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print("Categories in 'sex' variable:  ",end=" ")
print(df['sex'].unique())

print("Categories in 'famsize' variable:  ",end=" ")
print(df['famsize'].unique())

print("Categories in 'Mjob' variable:  ",end=" ")
print(df['Mjob'].unique())

print("Categories in 'age' variable:  ",end=" ")
print(df['age'].unique())


print("Categories in 'freetime' variable:  ",end=" ")
print(df['freetime'].unique())
# Out:
# Categories in 'sex' variable:   ['F' 'M']
# Categories in 'famsize' variable:   ['GT3' 'LE3']
# Categories in 'Mjob' variable:   ['at_home' 'health' 'other' 'services' 'teacher']
# Categories in 'age' variable:   [18 17 15 16 19 22 20 21]
# Categories in 'freetime' variable:   [3 2 4 1 5]

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype !='O' ]
categorical_features = [feature for feature in df.columns if df[feature].dtype =='O' ]

#print columns
print('We have {} numerical features :'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features :'.format(len(categorical_features), categorical_features))
# Out:
# We have 16 numerical features :
#
# We have 17 categorical features :

# %%
df.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0      4        3      4     1     1      3        6  5  6  6
# 1      5        3      3     1     1      3        4  5  5  6
#
# [2 rows x 33 columns]

# %%
df['total score'] =  df['age'] + df['health'] + df['freetime']
df['average'] = df['total score']/3
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   goout Dalc  Walc  health  absences  G1  G2  G3 total score   average
# 0     4    1     1       3         6   5   6   6          24  8.000000
# 1     3    1     1       3         4   5   5   6          23  7.666667
# 2     2    2     3       3        10   7   8  10          21  7.000000
# 3     2    1     1       5         2  15  14  15          22  7.333333
# 4     2    1     2       5         4   6  10  10          24  8.000000
#
# [5 rows x 35 columns]

# %%
good_health = df[df['health'] == 100]['average'].count()
free = df[df['freetime'] == 100]['average'].count()

print(f'Number of student with good health:  {good_health}')
print(f'Number of student with free time:  {free}')
# Out:
# Number of student with good health:  0
# Number of student with free time:  0

# %% [markdown]
# Histogram & KDE

# %%
fig, axs = plt.subplots(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='sex')
plt.show()

# %%
fig, axs = plt.subplots(1,2, figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='total score',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='total score',bins=30,kde=True,hue='sex')
plt.show()

# %% [markdown]
# Female students tend to perform well than male students

# %%
fig, axs = plt.subplots(1,3, figsize=(15,7))
plt.subplot(141)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='freetime')
plt.subplot(142)
sns.histplot(data=df[df.sex=='F'],x='average',kde=True,hue='freetime')
plt.subplot(142)
sns.histplot(data=df[df.sex=='M'],x='average',kde=True,hue='freetime')

plt.show()

# %%
fig, axs = plt.subplots(1,3, figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='health')
plt.subplot(142)
sns.histplot(data=df[df.sex=='F'],x='average',kde=True,hue='health')
plt.subplot(142)
sns.histplot(data=df[df.sex=='M'],x='average',kde=True,hue='health')

plt.show()
